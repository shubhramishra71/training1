# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### <b>Shubhra Mishra</b>
# ## Business Intelligence Consultant

# %% [markdown]
# <i>Data Science intrigues me. Working with data satisfies my curiosity.</i>

# %% [markdown]
# ### This code will do basic math

# %%
print ( 9*3)
# Out:
# 27

# %% [markdown]
# #Testing numbered items
# 1. Test 1
# 1. Test 2
# 3. Test 3
#
# <img src=“https://imgur.com/t/birds/oTrRb7F” alt=“Bird” title=“Chipping Sparrow” />
#
# __[Test link]https://www.bbc.co.uk/news)__
